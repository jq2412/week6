# %% [markdown]
# <a href="https://colab.research.google.com/github/tleitchColumbia/week6/blob/main/Pandas_Indexing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
names = ['alan','bob','charlie']
ages = [20,30,40]
city = ['NY','NY','TX']

# %%
mydata = list(zip(names,ages,city))

# %%
mydata
# Out:
# [('alan', 20, 'NY'), ('bob', 30, 'NY'), ('charlie', 40, 'TX')]

# %%
df = pd.DataFrame(data = mydata)

# %%
df
# Out:
#          0   1   2
# 0     alan  20  NY
# 1      bob  30  NY
# 2  charlie  40  TX

# %%
df = pd.DataFrame(data = mydata, columns=['names','ages','city'])

# %%
df
# Out:
#      names  ages city
# 0     alan    20   NY
# 1      bob    30   NY
# 2  charlie    40   TX

# %%
df = pd.DataFrame(data = mydata, columns=['names','ages','city'],index = ['one','two','three'])

# %%
df
# Out:
#          names  ages city
# one       alan    20   NY
# two        bob    30   NY
# three  charlie    40   TX

# %%
df.loc[['one','two'],"names"]
# Out:
# one    alan
# two     bob
# Name: names, dtype: object

# %%
df.to_csv('df.csv')

# %%
df2 = pd.read_csv('df.csv')

# %%
df2
# Out:
#   Unnamed: 0    names  ages city
# 0        one     alan    20   NY
# 1        two      bob    30   NY
# 2      three  charlie    40   TX

# %%
df.iloc[:2,1:3]
# Out:
#      ages city
# one    20   NY
# two    30   NY

# %%
df2.index = df2.iloc[:,0]

# %%
del df2[df2.columns[0]]

# %%
df2
# Out:
#               names  ages city
# Unnamed: 0
# one            alan    20   NY
# two             bob    30   NY
# three       charlie    40   TX

# %%
df2.index.name = 'hi'

# %%
df2.loc["one",'city']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-c7455e34cfba> in <cell line: 1>()
# ----> 1 df2.loc["one",'city']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1094             key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1095             if self._is_scalar_access(key):
# -> 1096                 return self.obj._get_value(*key, takeable=self._takeable)
#    1097             return self._getitem_tuple(key)
#    1098         else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3875             #  results if our categories are integers that dont match our codes
#    3876             # IntervalIndex: IntervalTree has no get_loc
# -> 3877             row = self.index.get_loc(index)
#    3878             return series._values[row]
#    3879
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     347                 raise KeyError(key) from err
#     348         if isinstance(key, Hashable):
# --> 349             raise KeyError(key)
#     350         self._check_indexing_error(key)
#     351         raise KeyError(key)
#
# KeyError: 'one'

# %%
df2.iloc[:,3]
# Out:
# hi
# 0    NY
# 1    NY
# 2    TX
# Name: city, dtype: object

# %%
# Filter
df.loc[df['names']=='alan']
# Out:
#     names  ages city
# one  alan    20   NY

# %%
# Select
df.loc[:,['ages']]
# Out:
#        ages
# one      20
# two      30
# three    40

# %%
# Arrange
df.sort_values('ages',ascending=0)
# Out:
#          names  ages city
# three  charlie    40   TX
# two        bob    30   NY
# one       alan    20   NY

# %%
# Mutate
df['FaveCity'] = df['city'] == 'NY'

# %%
df
# Out:
#          names  ages city  FaveCity
# one       alan    20   NY      True
# two        bob    30   NY      True
# three  charlie    40   TX     False

# %%
# Groupby & Summarize
df.groupby('city')["ages"].mean()
# Out:
# city
# NY    25.0
# TX    40.0
# Name: ages, dtype: float64
